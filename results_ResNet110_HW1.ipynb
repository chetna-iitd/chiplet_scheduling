# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints_1 = np.array([118158425/30000000000, 348807601/30000000000, 7650510409/30000000000])#Latency_exp1
xpoints_2 = np.array([92923794/30000000000, 255466466/30000000000, 5673442130/30000000000])#Latency_exp2
xpoints_3 = np.array([551523922/30000000000, 1977817302/30000000000, 47877832266/30000000000])#Latency_exp3
ypoints_accx = np.array([32.86, 43.78, 80.7])#accuracy_exits
latency1=np.array([7655510409/30000000000])
latency2=np.array([5675451604/30000000000])
latency3=np.array([47904913522/30000000000])
energy1=np.array([127746])
energy2=np.array([21335803])
energy3=np.array([14367])
acc=np.array([79.17])
energy1_all = np.array([43195, 84508, 125822])#energy_exp1
energy2_all = np.array([3873558, 7592018, 11310478])#energy_exp2
energy3_all = np.array([4892, 9433, 13975])#energy_exp3

fig, ax=plt.subplots()
plt.scatter(xpoints_2, ypoints_accx, s=100, marker='d', color='k', linewidth=4)
plt.scatter(latency2, acc, s=80, marker='d', color='g', linewidth=4)
plt.scatter(xpoints_1, ypoints_accx, s=200, marker='x', color='k', linewidth=4)
plt.scatter(latency1, acc, s=100, marker='x', color='g', linewidth=4)
plt.scatter(xpoints_3, ypoints_accx, s=200, marker='.', color='k', linewidth=4)
plt.scatter(latency3, acc, s=100, marker='.', color='g', linewidth=4)

plt.text(1000000000/30000000000, 30, 'Exit-1', fontsize = 18)
plt.text(2500000000/30000000000, 42, 'Exit-2', fontsize = 18)
plt.text(9000000000/30000000000, 78, 'Exit-3', fontsize = 18)
plt.xlabel('Latency [s]')
plt.ylabel('Quality mAP [%]')
COLOR1 = 'black'
plt.rcParams['text.color'] = COLOR1
plt.rcParams['axes.labelcolor'] = COLOR1
plt.rcParams['xtick.color'] = COLOR1
plt.rcParams['ytick.color'] = COLOR1
plt.rcParams['figure.facecolor'] = 'white'
plt.ylim(0,85)
plt.xlim(-2500000000/50000000000,85000000000/50000000000)
rect=plt.Rectangle(xy=(0.15,0), width=50000000000/1000000000, height=85, color='coral',alpha=0.3 )
rect1=plt.Rectangle(xy=(-0.1,0), width=.25, height=40, color='coral',alpha=0.3 )
rect2=plt.Rectangle(xy=(-0.1,40), width=.25, height=45, color='green',alpha=0.07 )
ax.add_patch(rect)
ax.add_patch(rect1)
ax.add_patch(rect2)
#plt.fill_between(range(len(s)), min(s), max(s), where=(s < 1.25) & (s > 0.75), alpha=0.5)
#plt.legend(["split+drop" , "split+no-drop", "part-split+drop" , "part-split+no-drop","no-split+drop" , "no-split+no-drop"], ncol = 1 , bbox_to_anchor = (1.05 , 0.9), frameon=False)#loc = "lower right")
plt.grid()
plt.rcParams.update({'font.size': 20})
plt.savefig('qual_lat_res_hw1.pdf',bbox_inches='tight')
plt.show()
plt.close()

# %%
import matplotlib.pyplot as plt2
import numpy as np

xpoints_1 = np.array([118158425/30000000000, 348807601/30000000000, 7650510409/30000000000])#Latency_exp1
xpoints_2 = np.array([92923794/30000000000, 255466466/30000000000, 5673442130/30000000000])#Latency_exp2
xpoints_3 = np.array([551523922/30000000000, 1977817302/30000000000, 47877832266/30000000000])#Latency_exp3
ypoints_accx = np.array([32.86, 43.78, 80.7])#accuracy_exits
latency1=np.array([7655510409/30000000000])
latency2=np.array([5675451604/30000000000])
latency3=np.array([47904913522/30000000000])
energy1_=np.array([127746/50000])
energy2_=np.array([21335803/50000])
energy3_=np.array([14367/50000])
acc=np.array([79.17])
energy1_all_ = np.array([43195/50000, 84508/50000, 125822/50000])#energy_exp1
energy2_all_ = np.array([3873558/50000, 7592018/50000, 11310478/50000])#energy_exp2
energy3_all_ = np.array([4892/50000, 9433/50000, 13975/50000])#energy_exp3
energy1=np.multiply(energy1_,latency1)
energy2=np.multiply(energy2_,latency2)
energy3=np.multiply(energy3_,latency3)
acc=np.array([79.17])
energy1_all=np.multiply(energy1_all_,xpoints_1)
energy2_all=np.multiply(energy2_all_,xpoints_2)
energy3_all=np.multiply(energy3_all_,xpoints_3)
#print(energy1_all)
#print(energy2_all)
#print(energy3_all)

fig, ax1=plt2.subplots()
plt2.scatter(xpoints_2, energy2_all, s=100, marker='d', color='k', linewidth=4)
plt2.scatter(latency2, energy2, s=80, marker='d', color='g', linewidth=4)
plt2.scatter(xpoints_1, energy1_all, s=200, marker='x', color='k', linewidth=4)
plt2.scatter(latency1, energy1, s=100, marker='x', color='g', linewidth=4)
plt2.scatter(xpoints_3, energy3_all, s=200, marker='.', color='k', linewidth=4)
plt2.scatter(latency3, energy3, s=100, marker='.', color='g', linewidth=4)
#plt.legend(["split+drop" , "split+no-drop", "part-split+drop" , "part-split+no-drop","no-split+drop" , "no-split+no-drop"], ncol = 3 , bbox_to_anchor = (.01 , 0.34), frameon=True)#loc = "lower right")
plt2.xlabel('Latency [s]')
plt2.ylabel('Energy [J]')
COLOR11 = 'black'
plt2.rcParams['text.color'] = COLOR11
plt2.rcParams['axes.labelcolor'] = COLOR11
plt2.rcParams['xtick.color'] = COLOR11
plt2.rcParams['ytick.color'] = COLOR11
plt2.ylim(-8,100)
plt2.xlim(-2500000000/50000000000,85000000000/50000000000)
rect3=plt2.Rectangle(xy=(0.15,-10), width=1.6, height=120, color='coral',alpha=0.3 )
ax1.add_patch(rect3)
rect2=plt2.Rectangle(xy=(-2500000000/50000000000,-8), width=0.2, height=120, color='green',alpha=0.07 )
ax1.add_patch(rect2)
#ax1.add_patch(rect3)
plt2.grid()
plt2.rcParams.update({'font.size': 20})
plt2.savefig('energy_lat_res_hw1.pdf',bbox_inches='tight')
#plt2.savefig('energy_lat_2.png',bbox_inches='tight',transparent=None,dpi=fig.dpi)
plt2.show()
plt2.close()
#plt.close()

# %%
import matplotlib.pyplot as plt1
import numpy as np

##plotting legend

plt1.figure(figsize=(0.001,0.001))
plt1.scatter(0,0, s=100, marker='d', color='k', linewidth=4)
plt1.scatter(0,0, s=80, marker='d', color='g', linewidth=4)
plt1.scatter(0,0, s=200, marker='x', color='k', linewidth=4)
plt1.scatter(0,0, s=100, marker='x', color='g', linewidth=4)
plt1.scatter(0,0, s=200, marker='.', color='k', linewidth=4)
plt1.scatter(0,0, s=100, marker='.', color='g', linewidth=4)
#plt.xlabel('Latency [cycles]')
#plt.ylabel('Power [W]')
plt1.ylim(0.2,0.3)
plt1.ylim(0.01,0.1)
COLOR = 'white'
plt1.rcParams['text.color'] = COLOR
plt1.rcParams['axes.labelcolor'] = COLOR
plt1.rcParams['xtick.color'] = COLOR
plt1.rcParams['ytick.color'] = COLOR
plt1.rcParams['figure.facecolor'] = COLOR
plt1.legend(["split+drop" , "split+no-drop", "part-split+drop" , "part-split+no-drop","no-split+drop" , "no-split+no-drop"], ncol = 3 , bbox_to_anchor = (.5 , 0.5), frameon=True, labelcolor='black')#loc = "lower right")
#plt.grid()
plt1.rcParams.update({'font.size': 20})
plt1.savefig('legend.pdf',bbox_inches='tight')
plt1.show()
plt1.close()
